# %%
from pypde import *
from dns import rbc2d
from dns import rbc2d_adj
import matplotlib.pyplot as plt

blue = (0 / 255, 137 / 255, 204 / 255)
red = (196 / 255, 0, 96 / 255)
yel = (230 / 255, 159 / 255, 0)

initplot()


def avg_x(f, dx):
    return np.sum(f * dx[:, None], axis=0) / np.sum(dx)


shape = (164, 164)

Pr = 1
Ra = np.logspace(5, 6, 10)
Ra = [1.05e5]
Nu = []
aspect = 1.0
adiabatic = False

time = 0.0
e1, e2, e3 = [], [], []
for R in Ra:
    # -- Solve Navier Stokes
    NS = rbc2d.NavierStokes(
        adiabatic=adiabatic,
        shape=shape,
        dt=0.1,
        tsave=1.0,
        Ra=R,
        Pr=Pr,
        dealias=True,
        integrator="rk3",
        beta=1.0,
        aspect=aspect,
    )
    NS.set_temperature(m=1, amplitude=0.05)
    NS.iterate(220.0)
    # NS.solve_steady_state()
    # evals, _ = NS.solve_stability(shape=(21, 21), plot=True)

    # -- Animate and plot
    NS.plot()
    #NS.animate()

    # -- Evaluate Nu
    Nuz, Nuv = NS.eval_Nu()
    Nu.append(Nuz)

    # Adjoint iteration
    U = NS.U.vhat[:].copy()
    V = NS.V.vhat[:].copy()
    T = NS.T.vhat[:].copy()

    NSA = rbc2d_adj.NavierStokesAdjoint(
        adiabatic=adiabatic,
        shape=shape,
        dt=0.1,
        tsave=1.0,
        Ra=R,
        Pr=Pr,
        dealias=True,
        integrator="rk3",
        beta=1.0,
        aspect=aspect,
    )

    NSA.NS.U.vhat[:] = U
    NSA.NS.V.vhat[:] = V
    NSA.NS.T.vhat[:] = T

    NSA.U.vhat[:] = U
    NSA.V.vhat[:] = V
    NSA.T.vhat[:] = T

    NSA.iterate(80.0)
    NSA.plot()

    NS.U.vhat[:] = NSA.U.vhat[:]
    NS.V.vhat[:] = NSA.V.vhat[:]
    NS.T.vhat[:] = NSA.T.vhat[:]
    Nuz, Nuv = NS.eval_Nu()

    NS.solve_steady_state(maxiter=500)
    Nuz, Nuv = NS.eval_Nu()
    NS.plot() 
    NS.solve_stability()
    NS.write(add_time=False)
# Out:
# set color cycle ...
# register goldfish colorbar as 'gfcmap' ...
# update rc params to default ...
# set color cycle ...
# register goldfish colorbar as 'gfcmap' ...
# update rc params to default ...
# Initialize rk3 ...
# /home/philipp/Python/pypde/pypde/plot/initplot.py:124: UserWarning: Trying to register the cmap 'gfcmap' which already exists.
#   plt.cm.register_cmap(name="gfcmap", cmap=gfcmap())
# Time: 1.000
# Divergence: 2.04e-04
# Time: 2.000
# Divergence: 1.00e-04
# Time: 3.000
# Divergence: 7.87e-05
# Time: 4.000
# Divergence: 9.54e-05
# Time: 5.000
# Divergence: 1.43e-04
# Time: 6.000
# Divergence: 1.47e-04
# Time: 7.000
# Divergence: 1.63e-04
# Time: 8.000
# Divergence: 1.26e-04
# Time: 9.000
# Divergence: 1.37e-04
# Time: 10.000
# Divergence: 1.24e-04
# Time: 11.000
# Divergence: 1.03e-04
# Time: 12.000
# Divergence: 8.50e-05
# Time: 13.000
# Divergence: 7.61e-05
# Time: 14.000
# Divergence: 7.85e-05
# Time: 15.000
# Divergence: 9.45e-05
# Time: 16.000
# Divergence: 1.01e-04
# Time: 17.000
# Divergence: 8.04e-05
# Time: 18.000
# Divergence: 8.00e-05
# Time: 19.000
# Divergence: 9.11e-05
# Time: 20.000
# Divergence: 9.26e-05
# Time: 21.000
# Divergence: 8.53e-05
# Time: 22.000
# Divergence: 7.49e-05
# Time: 23.000
# Divergence: 6.58e-05
# Time: 24.000
# Divergence: 6.08e-05
# Time: 25.000
# Divergence: 6.18e-05
# Time: 26.000
# Divergence: 6.85e-05
# Time: 27.000
# Divergence: 7.71e-05
# Time: 28.000
# Divergence: 7.92e-05
# Time: 29.000
# Divergence: 7.41e-05
# Time: 30.000
# Divergence: 7.22e-05
# Time: 31.000
# Divergence: 7.67e-05
# Time: 32.000
# Divergence: 8.16e-05
# Time: 33.000
# Divergence: 8.21e-05
# Time: 34.000
# Divergence: 7.88e-05
# Time: 35.000
# Divergence: 7.39e-05
# Time: 36.000
# Divergence: 6.97e-05
# Time: 37.000
# Divergence: 6.78e-05
# Time: 38.000
# Divergence: 6.87e-05
# Time: 39.000
# Divergence: 7.19e-05
# Time: 40.000
# Divergence: 7.58e-05
# Time: 41.000
# Divergence: 7.81e-05
# Time: 42.000
# Divergence: 7.84e-05
# Time: 43.000
# Divergence: 7.83e-05
# Time: 44.000
# Divergence: 7.95e-05
# Time: 45.000
# Divergence: 8.19e-05
# Time: 46.000
# Divergence: 8.42e-05
# Time: 47.000
# Divergence: 8.55e-05
# Time: 48.000
# Divergence: 8.57e-05
# Time: 49.000
# Divergence: 8.53e-05
# Time: 50.000
# Divergence: 8.51e-05
# Time: 51.000
# Divergence: 8.55e-05
# Time: 52.000
# Divergence: 8.68e-05
# Time: 53.000
# Divergence: 8.83e-05
# Time: 54.000
# Divergence: 8.94e-05
# Time: 55.000
# Divergence: 8.88e-05
# Time: 56.000
# Divergence: 8.62e-05
# Time: 57.000
# Divergence: 8.25e-05
# Time: 58.000
# Divergence: 7.99e-05
# Time: 59.000
# Divergence: 8.10e-05
# Time: 60.000
# Divergence: 8.85e-05
# Time: 61.000
# Divergence: 9.32e-05
# Time: 62.000
# Divergence: 8.60e-05
# Time: 63.000
# Divergence: 1.04e-04
# Time: 64.000
# Divergence: 1.20e-04
# Time: 65.000
# Divergence: 1.16e-04
# Time: 66.000
# Divergence: 1.05e-04
# Time: 67.000
# Divergence: 9.37e-05
# Time: 68.000
# Divergence: 8.47e-05
# Time: 69.000
# Divergence: 7.91e-05
# Time: 70.000
# Divergence: 7.71e-05
# Time: 71.000
# Divergence: 7.74e-05
# Time: 72.000
# Divergence: 7.87e-05
# Time: 73.000
# Divergence: 8.10e-05
# Time: 74.000
# Divergence: 8.35e-05
# Time: 75.000
# Divergence: 8.55e-05
# Time: 76.000
# Divergence: 8.60e-05
# Time: 77.000
# Divergence: 1.03e-04
# Time: 78.000
# Divergence: 1.14e-04
# Time: 79.000
# Divergence: 1.09e-04
# Time: 80.000
# Divergence: 9.73e-05
# Time: 81.000
# Divergence: 8.55e-05
# Time: 82.000
# Divergence: 7.60e-05
# Time: 83.000
# Divergence: 7.01e-05
# Time: 84.000
# Divergence: 6.86e-05
# Time: 85.000
# Divergence: 7.09e-05
# Time: 86.000
# Divergence: 7.55e-05
# Time: 87.000
# Divergence: 7.96e-05
# Time: 88.000
# Divergence: 8.12e-05
# Time: 89.000
# Divergence: 8.08e-05
# Time: 90.000
# Divergence: 8.23e-05
# Time: 91.000
# Divergence: 8.78e-05
# Time: 92.000
# Divergence: 8.71e-05
# Time: 93.000
# Divergence: 8.18e-05
# Time: 94.000
# Divergence: 9.23e-05
# Time: 95.000
# Divergence: 1.04e-04
# Time: 96.000
# Divergence: 1.04e-04
# Time: 97.000
# Divergence: 9.81e-05
# Time: 98.000
# Divergence: 9.12e-05
# Time: 99.000
# Divergence: 8.58e-05
# Time: 100.000
# Divergence: 8.31e-05
# Time: 101.000
# Divergence: 8.30e-05
# Time: 102.000
# Divergence: 8.41e-05
# Time: 103.000
# Divergence: 8.43e-05
# Time: 104.000
# Divergence: 8.47e-05
# Time: 105.000
# Divergence: 8.66e-05
# Time: 106.000
# Divergence: 9.05e-05
# Time: 107.000
# Divergence: 8.83e-05
# Time: 108.000
# Divergence: 9.90e-05
# Time: 109.000
# Divergence: 1.20e-04
# Time: 110.000
# Divergence: 1.19e-04
# Time: 111.000
# Divergence: 1.08e-04
# Time: 112.000
# Divergence: 9.53e-05
# Time: 113.000
# Divergence: 8.48e-05
# Time: 114.000
# Divergence: 7.77e-05
# Time: 115.000
# Divergence: 7.44e-05
# Time: 116.000
# Divergence: 7.44e-05
# Time: 117.000
# Divergence: 7.62e-05
# Time: 118.000
# Divergence: 7.87e-05
# Time: 119.000
# Divergence: 8.12e-05
# Time: 120.000
# Divergence: 8.43e-05
# Time: 121.000
# Divergence: 8.55e-05
# Time: 122.000
# Divergence: 8.96e-05
# Time: 123.000
# Divergence: 1.08e-04
# Time: 124.000
# Divergence: 1.14e-04
# Time: 125.000
# Divergence: 1.07e-04
# Time: 126.000
# Divergence: 9.61e-05
# Time: 127.000
# Divergence: 8.57e-05
# Time: 128.000
# Divergence: 7.81e-05
# Time: 129.000
# Divergence: 7.42e-05
# Time: 130.000
# Divergence: 7.40e-05
# Time: 131.000
# Divergence: 7.62e-05
# Time: 132.000
# Divergence: 7.90e-05
# Time: 133.000
# Divergence: 8.14e-05
# Time: 134.000
# Divergence: 8.34e-05
# Time: 135.000
# Divergence: 8.74e-05
# Time: 136.000
# Divergence: 8.79e-05
# Time: 137.000
# Divergence: 8.92e-05
# Time: 138.000
# Divergence: 1.08e-04
# Time: 139.000
# Divergence: 1.15e-04
# Time: 140.000
# Divergence: 1.09e-04
# Time: 141.000
# Divergence: 9.87e-05
# Time: 142.000
# Divergence: 8.92e-05
# Time: 143.000
# Divergence: 8.25e-05
# Time: 144.000
# Divergence: 7.92e-05
# Time: 145.000
# Divergence: 7.90e-05
# Time: 146.000
# Divergence: 8.01e-05
# Time: 147.000
# Divergence: 8.14e-05
# Time: 148.000
# Divergence: 8.38e-05
# Time: 149.000
# Divergence: 8.67e-05
# Time: 150.000
# Divergence: 8.72e-05
# Time: 151.000
# Divergence: 8.99e-05
# Time: 152.000
# Divergence: 1.11e-04
# Time: 153.000
# Divergence: 1.18e-04
# Time: 154.000
# Divergence: 1.10e-04
# Time: 155.000
# Divergence: 9.79e-05
# Time: 156.000
# Divergence: 8.66e-05
# Time: 157.000
# Divergence: 7.82e-05
# Time: 158.000
# Divergence: 7.35e-05
# Time: 159.000
# Divergence: 7.25e-05
# Time: 160.000
# Divergence: 7.44e-05
# Time: 161.000
# Divergence: 7.73e-05
# Time: 162.000
# Divergence: 8.02e-05
# Time: 163.000
# Divergence: 8.26e-05
# Time: 164.000
# Divergence: 8.66e-05
# Time: 165.000
# Divergence: 8.69e-05
# Time: 166.000
# Divergence: 9.10e-05
# Time: 167.000
# Divergence: 1.09e-04
# Time: 168.000
# Divergence: 1.14e-04
# Time: 169.000
# Divergence: 1.07e-04
# Time: 170.000
# Divergence: 9.71e-05
# Time: 171.000
# Divergence: 8.79e-05
# Time: 172.000
# Divergence: 8.15e-05
# Time: 173.000
# Divergence: 7.87e-05
# Time: 174.000
# Divergence: 7.87e-05
# Time: 175.000
# Divergence: 8.00e-05
# Time: 176.000
# Divergence: 8.15e-05
# Time: 177.000
# Divergence: 8.38e-05
# Time: 178.000
# Divergence: 8.69e-05
# Time: 179.000
# Divergence: 8.73e-05
# Time: 180.000
# Divergence: 9.01e-05
# Time: 181.000
# Divergence: 1.11e-04
# Time: 182.000
# Divergence: 1.18e-04
# Time: 183.000
# Divergence: 1.10e-04
# Time: 184.000
# Divergence: 9.81e-05
# Time: 185.000
# Divergence: 8.70e-05
# Time: 186.000
# Divergence: 7.87e-05
# Time: 187.000
# Divergence: 7.42e-05
# Time: 188.000
# Divergence: 7.34e-05
# Time: 189.000
# Divergence: 7.52e-05
# Time: 190.000
# Divergence: 7.78e-05
# Time: 191.000
# Divergence: 8.06e-05
# Time: 192.000
# Divergence: 8.30e-05
# Time: 193.000
# Divergence: 8.68e-05
# Time: 194.000
# Divergence: 8.63e-05
# Time: 195.000
# Divergence: 9.46e-05
# Time: 196.000
# Divergence: 1.12e-04
# Time: 197.000
# Divergence: 1.14e-04
# Time: 198.000
# Divergence: 1.05e-04
# Time: 199.000
# Divergence: 9.47e-05
# Time: 200.000
# Divergence: 8.56e-05
# Time: 201.000
# Divergence: 7.96e-05
# Time: 202.000
# Divergence: 7.72e-05
# Time: 203.000
# Divergence: 7.77e-05
# Time: 204.000
# Divergence: 7.93e-05
# Time: 205.000
# Divergence: 8.12e-05
# Time: 206.000
# Divergence: 8.36e-05
# Time: 207.000
# Divergence: 8.68e-05
# Time: 208.000
# Divergence: 8.71e-05
# Time: 209.000
# Divergence: 9.05e-05
# Time: 210.000
# Divergence: 1.11e-04
# Time: 211.000
# Divergence: 1.17e-04
# Time: 212.000
# Divergence: 1.09e-04
# Time: 213.000
# Divergence: 9.76e-05
# Time: 214.000
# Divergence: 8.69e-05
# Time: 215.000
# Divergence: 7.91e-05
# Time: 216.000
# Divergence: 7.50e-05
# Time: 217.000
# Divergence: 7.45e-05
# Time: 218.000
# Divergence: 7.62e-05
# Time: 219.000
# Divergence: 7.86e-05
# Time: 220.000
# Divergence: 8.13e-05
# Nubot: 2.585206e+00
# Nutop: 2.585206e+00
# Nuvol: 3.525742e+00
# Initialize rk3 ...
# Time: 1.000
# Divergence   : 6.74e-02
# Divergence NS: 7.24e-01
#  |U| = 3.26e-02
#  |V| = 3.85e-02
#  |T| = 6.21e-03
# Time: 2.000
# Divergence   : 2.57e-02
# Divergence NS: 2.52e-01
#  |U| = 2.27e-02
#  |V| = 2.06e-02
#  |T| = 3.84e-03
# Time: 3.000
# Divergence   : 4.08e-02
# Divergence NS: 4.04e-01
#  |U| = 2.07e-02
#  |V| = 2.13e-02
#  |T| = 3.19e-03
# Time: 4.000
# Divergence   : 4.93e-02
# Divergence NS: 4.91e-01
#  |U| = 2.00e-02
#  |V| = 2.20e-02
#  |T| = 2.88e-03
# Time: 5.000
# Divergence   : 5.45e-02
# Divergence NS: 5.44e-01
#  |U| = 1.99e-02
#  |V| = 2.21e-02
#  |T| = 2.71e-03
# Time: 6.000
# Divergence   : 5.78e-02
# Divergence NS: 5.78e-01
#  |U| = 1.98e-02
#  |V| = 2.19e-02
#  |T| = 2.63e-03
# Time: 7.000
# Divergence   : 5.99e-02
# Divergence NS: 5.99e-01
#  |U| = 1.99e-02
#  |V| = 2.15e-02
#  |T| = 2.58e-03
# Time: 8.000
# Divergence   : 6.10e-02
# Divergence NS: 6.11e-01
#  |U| = 1.99e-02
#  |V| = 2.11e-02
#  |T| = 2.56e-03
# Time: 9.000
# Divergence   : 6.15e-02
# Divergence NS: 6.16e-01
#  |U| = 1.99e-02
#  |V| = 2.07e-02
#  |T| = 2.53e-03
# Time: 10.000
# Divergence   : 6.16e-02
# Divergence NS: 6.16e-01
#  |U| = 1.98e-02
#  |V| = 2.02e-02
#  |T| = 2.51e-03
# Time: 11.000
# Divergence   : 6.12e-02
# Divergence NS: 6.13e-01
#  |U| = 1.97e-02
#  |V| = 1.98e-02
#  |T| = 2.49e-03
# Time: 12.000
# Divergence   : 6.07e-02
# Divergence NS: 6.08e-01
#  |U| = 1.95e-02
#  |V| = 1.93e-02
#  |T| = 2.46e-03
# Time: 13.000
# Divergence   : 5.99e-02
# Divergence NS: 6.00e-01
#  |U| = 1.93e-02
#  |V| = 1.88e-02
#  |T| = 2.43e-03
# Time: 14.000
# Divergence   : 5.91e-02
# Divergence NS: 5.92e-01
#  |U| = 1.91e-02
#  |V| = 1.84e-02
#  |T| = 2.40e-03
# Time: 15.000
# Divergence   : 5.81e-02
# Divergence NS: 5.82e-01
#  |U| = 1.89e-02
#  |V| = 1.80e-02
#  |T| = 2.36e-03
# Time: 16.000
# Divergence   : 5.71e-02
# Divergence NS: 5.72e-01
#  |U| = 1.86e-02
#  |V| = 1.75e-02
#  |T| = 2.32e-03
# Time: 17.000
# Divergence   : 5.60e-02
# Divergence NS: 5.61e-01
#  |U| = 1.83e-02
#  |V| = 1.71e-02
#  |T| = 2.29e-03
# Time: 18.000
# Divergence   : 5.50e-02
# Divergence NS: 5.50e-01
#  |U| = 1.80e-02
#  |V| = 1.67e-02
#  |T| = 2.25e-03
# Time: 19.000
# Divergence   : 5.39e-02
# Divergence NS: 5.40e-01
#  |U| = 1.77e-02
#  |V| = 1.63e-02
#  |T| = 2.21e-03
# Time: 20.000
# Divergence   : 5.28e-02
# Divergence NS: 5.29e-01
#  |U| = 1.74e-02
#  |V| = 1.59e-02
#  |T| = 2.17e-03
# Time: 21.000
# Divergence   : 5.17e-02
# Divergence NS: 5.18e-01
#  |U| = 1.71e-02
#  |V| = 1.56e-02
#  |T| = 2.13e-03
# Time: 22.000
# Divergence   : 5.06e-02
# Divergence NS: 5.07e-01
#  |U| = 1.68e-02
#  |V| = 1.52e-02
#  |T| = 2.09e-03
# Time: 23.000
# Divergence   : 4.95e-02
# Divergence NS: 4.96e-01
#  |U| = 1.66e-02
#  |V| = 1.49e-02
#  |T| = 2.05e-03
# Time: 24.000
# Divergence   : 4.85e-02
# Divergence NS: 4.86e-01
#  |U| = 1.63e-02
#  |V| = 1.45e-02
#  |T| = 2.01e-03
# Time: 25.000
# Divergence   : 4.75e-02
# Divergence NS: 4.75e-01
#  |U| = 1.60e-02
#  |V| = 1.42e-02
#  |T| = 1.98e-03
# Time: 26.000
# Divergence   : 4.64e-02
# Divergence NS: 4.65e-01
#  |U| = 1.57e-02
#  |V| = 1.39e-02
#  |T| = 1.94e-03
# Time: 27.000
# Divergence   : 4.55e-02
# Divergence NS: 4.55e-01
#  |U| = 1.54e-02
#  |V| = 1.36e-02
#  |T| = 1.90e-03
# Time: 28.000
# Divergence   : 4.45e-02
# Divergence NS: 4.46e-01
#  |U| = 1.51e-02
#  |V| = 1.33e-02
#  |T| = 1.87e-03
# Time: 29.000
# Divergence   : 4.35e-02
# Divergence NS: 4.36e-01
#  |U| = 1.48e-02
#  |V| = 1.30e-02
#  |T| = 1.83e-03
# Time: 30.000
# Divergence   : 4.26e-02
# Divergence NS: 4.27e-01
#  |U| = 1.46e-02
#  |V| = 1.28e-02
#  |T| = 1.80e-03
# Time: 31.000
# Divergence   : 4.17e-02
# Divergence NS: 4.18e-01
#  |U| = 1.43e-02
#  |V| = 1.25e-02
#  |T| = 1.77e-03
# Time: 32.000
# Divergence   : 4.08e-02
# Divergence NS: 4.09e-01
#  |U| = 1.40e-02
#  |V| = 1.22e-02
#  |T| = 1.73e-03
# Time: 33.000
# Divergence   : 4.00e-02
# Divergence NS: 4.00e-01
#  |U| = 1.38e-02
#  |V| = 1.20e-02
#  |T| = 1.70e-03
# Time: 34.000
# Divergence   : 3.91e-02
# Divergence NS: 3.92e-01
#  |U| = 1.35e-02
#  |V| = 1.17e-02
#  |T| = 1.67e-03
# Time: 35.000
# Divergence   : 3.83e-02
# Divergence NS: 3.84e-01
#  |U| = 1.33e-02
#  |V| = 1.15e-02
#  |T| = 1.64e-03
# Time: 36.000
# Divergence   : 3.75e-02
# Divergence NS: 3.76e-01
#  |U| = 1.30e-02
#  |V| = 1.13e-02
#  |T| = 1.61e-03
# Time: 37.000
# Divergence   : 3.67e-02
# Divergence NS: 3.68e-01
#  |U| = 1.28e-02
#  |V| = 1.10e-02
#  |T| = 1.58e-03
# Time: 38.000
# Divergence   : 3.60e-02
# Divergence NS: 3.60e-01
#  |U| = 1.26e-02
#  |V| = 1.08e-02
#  |T| = 1.55e-03
# Time: 39.000
# Divergence   : 3.52e-02
# Divergence NS: 3.53e-01
#  |U| = 1.23e-02
#  |V| = 1.06e-02
#  |T| = 1.52e-03
# Time: 40.000
# Divergence   : 3.45e-02
# Divergence NS: 3.46e-01
#  |U| = 1.21e-02
#  |V| = 1.04e-02
#  |T| = 1.49e-03
# Time: 41.000
# Divergence   : 3.38e-02
# Divergence NS: 3.38e-01
#  |U| = 1.19e-02
#  |V| = 1.02e-02
#  |T| = 1.47e-03
# Time: 42.000
# Divergence   : 3.31e-02
# Divergence NS: 3.32e-01
#  |U| = 1.17e-02
#  |V| = 1.00e-02
#  |T| = 1.44e-03
# Time: 43.000
# Divergence   : 3.24e-02
# Divergence NS: 3.25e-01
#  |U| = 1.15e-02
#  |V| = 9.82e-03
#  |T| = 1.41e-03
# Time: 44.000
# Divergence   : 3.18e-02
# Divergence NS: 3.18e-01
#  |U| = 1.13e-02
#  |V| = 9.63e-03
#  |T| = 1.39e-03
# Time: 45.000
# Divergence   : 3.11e-02
# Divergence NS: 3.12e-01
#  |U| = 1.10e-02
#  |V| = 9.44e-03
#  |T| = 1.36e-03
# Time: 46.000
# Divergence   : 3.05e-02
# Divergence NS: 3.05e-01
#  |U| = 1.08e-02
#  |V| = 9.27e-03
#  |T| = 1.34e-03
# Time: 47.000
# Divergence   : 2.99e-02
# Divergence NS: 2.99e-01
#  |U| = 1.06e-02
#  |V| = 9.09e-03
#  |T| = 1.31e-03
# Time: 48.000
# Divergence   : 2.93e-02
# Divergence NS: 2.93e-01
#  |U| = 1.04e-02
#  |V| = 8.92e-03
#  |T| = 1.29e-03
# Time: 49.000
# Divergence   : 2.87e-02
# Divergence NS: 2.87e-01
#  |U| = 1.03e-02
#  |V| = 8.75e-03
#  |T| = 1.27e-03
# Time: 50.000
# Divergence   : 2.81e-02
# Divergence NS: 2.81e-01
#  |U| = 1.01e-02
#  |V| = 8.59e-03
#  |T| = 1.24e-03
# Time: 51.000
# Divergence   : 2.75e-02
# Divergence NS: 2.76e-01
#  |U| = 9.88e-03
#  |V| = 8.43e-03
#  |T| = 1.22e-03
# Time: 52.000
# Divergence   : 2.70e-02
# Divergence NS: 2.70e-01
#  |U| = 9.70e-03
#  |V| = 8.27e-03
#  |T| = 1.20e-03
# Time: 53.000
# Divergence   : 2.64e-02
# Divergence NS: 2.65e-01
#  |U| = 9.52e-03
#  |V| = 8.11e-03
#  |T| = 1.18e-03
# Time: 54.000
# Divergence   : 2.59e-02
# Divergence NS: 2.59e-01
#  |U| = 9.34e-03
#  |V| = 7.96e-03
#  |T| = 1.16e-03
# Time: 55.000
# Divergence   : 2.54e-02
# Divergence NS: 2.54e-01
#  |U| = 9.17e-03
#  |V| = 7.81e-03
#  |T| = 1.14e-03
# Time: 56.000
# Divergence   : 2.49e-02
# Divergence NS: 2.49e-01
#  |U| = 9.00e-03
#  |V| = 7.67e-03
#  |T| = 1.12e-03
# Time: 57.000
# Divergence   : 2.44e-02
# Divergence NS: 2.44e-01
#  |U| = 8.83e-03
#  |V| = 7.53e-03
#  |T| = 1.10e-03
# Time: 58.000
# Divergence   : 2.39e-02
# Divergence NS: 2.39e-01
#  |U| = 8.67e-03
#  |V| = 7.39e-03
#  |T| = 1.08e-03
# Time: 59.000
# Divergence   : 2.34e-02
# Divergence NS: 2.34e-01
#  |U| = 8.51e-03
#  |V| = 7.25e-03
#  |T| = 1.06e-03
# Time: 60.000
# Divergence   : 2.29e-02
# Divergence NS: 2.30e-01
#  |U| = 8.35e-03
#  |V| = 7.11e-03
#  |T| = 1.04e-03
# Time: 61.000
# Divergence   : 2.25e-02
# Divergence NS: 2.25e-01
#  |U| = 8.20e-03
#  |V| = 6.98e-03
#  |T| = 1.02e-03
# Time: 62.000
# Divergence   : 2.20e-02
# Divergence NS: 2.21e-01
#  |U| = 8.04e-03
#  |V| = 6.85e-03
#  |T| = 1.00e-03
# Time: 63.000
# Divergence   : 2.16e-02
# Divergence NS: 2.16e-01
#  |U| = 7.89e-03
#  |V| = 6.73e-03
#  |T| = 9.83e-04
# Time: 64.000
# Divergence   : 2.12e-02
# Divergence NS: 2.12e-01
#  |U| = 7.75e-03
#  |V| = 6.60e-03
#  |T| = 9.66e-04
# Time: 65.000
# Divergence   : 2.07e-02
# Divergence NS: 2.08e-01
#  |U| = 7.60e-03
#  |V| = 6.48e-03
#  |T| = 9.48e-04
# Time: 66.000
# Divergence   : 2.03e-02
# Divergence NS: 2.03e-01
#  |U| = 7.46e-03
#  |V| = 6.36e-03
#  |T| = 9.31e-04
# Time: 67.000
# Divergence   : 1.99e-02
# Divergence NS: 1.99e-01
#  |U| = 7.32e-03
#  |V| = 6.24e-03
#  |T| = 9.14e-04
# Time: 68.000
# Divergence   : 1.95e-02
# Divergence NS: 1.95e-01
#  |U| = 7.18e-03
#  |V| = 6.12e-03
#  |T| = 8.98e-04
# Time: 69.000
# Divergence   : 1.91e-02
# Divergence NS: 1.91e-01
#  |U| = 7.05e-03
#  |V| = 6.01e-03
#  |T| = 8.81e-04
# Time: 70.000
# Divergence   : 1.87e-02
# Divergence NS: 1.88e-01
#  |U| = 6.92e-03
#  |V| = 5.90e-03
#  |T| = 8.65e-04
# Time: 71.000
# Divergence   : 1.83e-02
# Divergence NS: 1.84e-01
#  |U| = 6.78e-03
#  |V| = 5.79e-03
#  |T| = 8.50e-04
# Time: 72.000
# Divergence   : 1.80e-02
# Divergence NS: 1.80e-01
#  |U| = 6.66e-03
#  |V| = 5.68e-03
#  |T| = 8.34e-04
# Time: 73.000
# Divergence   : 1.76e-02
# Divergence NS: 1.76e-01
#  |U| = 6.53e-03
#  |V| = 5.57e-03
#  |T| = 8.19e-04
# Time: 74.000
# Divergence   : 1.73e-02
# Divergence NS: 1.73e-01
#  |U| = 6.41e-03
#  |V| = 5.47e-03
#  |T| = 8.04e-04
# Time: 75.000
# Divergence   : 1.69e-02
# Divergence NS: 1.69e-01
#  |U| = 6.28e-03
#  |V| = 5.36e-03
#  |T| = 7.90e-04
# Time: 76.000
# Divergence   : 1.66e-02
# Divergence NS: 1.66e-01
#  |U| = 6.16e-03
#  |V| = 5.26e-03
#  |T| = 7.75e-04
# Time: 77.000
# Divergence   : 1.62e-02
# Divergence NS: 1.62e-01
#  |U| = 6.05e-03
#  |V| = 5.16e-03
#  |T| = 7.61e-04
# Time: 78.000
# Divergence   : 1.59e-02
# Divergence NS: 1.59e-01
#  |U| = 5.93e-03
#  |V| = 5.06e-03
#  |T| = 7.47e-04
# Time: 79.000
# Divergence   : 1.56e-02
# Divergence NS: 1.56e-01
#  |U| = 5.82e-03
#  |V| = 4.97e-03
#  |T| = 7.33e-04
# Time: 80.000
# Divergence   : 1.52e-02
# Divergence NS: 1.53e-01
#  |U| = 5.71e-03
#  |V| = 4.87e-03
#  |T| = 7.20e-04
# Nubot: 2.507096e+00
# Nutop: 2.507096e+00
# Nuvol: 2.255948e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-84aceb5c03ef> in <module>
#      87     Nuz, Nuv = NS.eval_Nu()
#      88
# ---> 89     NS.solve_steady_state(maxiter=500)
#      90     Nuz, Nuv = NS.eval_Nu()
#      91     NS.plot()
#
# ~/Python/pypde/dns/rbc2d_base.py in solve_steady_state(self, X0, maxiter, disp, tol)
#     211         if X0 is None:
#     212             X0 = self.vectorify()
# --> 213         sol = optimize.root(
#     214             self.steady_fun, X0, args=(self,), method="krylov", options=options
#     215         )
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/optimize/_root.py in root(fun, x0, args, method, jac, tol, callback, options)
#     195                   'diagbroyden', 'excitingmixing', 'krylov'):
#     196         _warn_jac_unused(jac, method)
# --> 197         sol = _root_nonlin_solve(fun, x0, args=args, jac=jac,
#     198                                  _method=meth, _callback=callback,
#     199                                  **options)
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/optimize/_root.py in _root_nonlin_solve(fun, x0, args, jac, _callback, _method, nit, disp, maxiter, ftol, fatol, xtol, xatol, tol_norm, line_search, jac_options, **unknown_options)
#     293         f = fun
#     294
# --> 295     x, info = nonlin.nonlin_solve(f, x0, jacobian=jacobian(**jac_options),
#     296                                   iter=nit, verbose=verbose,
#     297                                   maxiter=maxiter, f_tol=f_tol,
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/optimize/nonlin.py in nonlin_solve(F, x0, jacobian, iter, verbose, maxiter, f_tol, f_rtol, x_tol, x_rtol, tol_norm, line_search, callback, full_output, raise_exception)
#     307         # The tolerance, as computed for scipy.sparse.linalg.* routines
#     308         tol = min(eta, eta*Fx_norm)
# --> 309         dx = -jacobian.solve(Fx, tol=tol)
#     310
#     311         if norm(dx) == 0:
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/optimize/nonlin.py in solve(self, rhs, tol)
#    1574             sol, info = self.method(self.op, rhs, **self.method_kw)
#    1575         else:
# -> 1576             sol, info = self.method(self.op, rhs, tol=tol, **self.method_kw)
#    1577         return sol
#    1578
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/sparse/linalg/isolve/lgmres.py in lgmres(A, b, x0, tol, maxiter, M, callback, inner_m, outer_k, outer_v, store_outer_Av, prepend_outer_v, atol)
#     180
#     181         try:
# --> 182             Q, R, B, vs, zs, y, pres = _fgmres(matvec,
#     183                                                v0,
#     184                                                inner_m,
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/sparse/linalg/isolve/_gcrotmk.py in _fgmres(matvec, v0, m, atol, lpsolve, rpsolve, cs, outer_v, prepend_outer_v)
#     102
#     103         if w is None:
# --> 104             w = lpsolve(matvec(z))
#     105         else:
#     106             # w is clobbered below
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/sparse/linalg/interface.py in matvec(self, x)
#     230             raise ValueError('dimension mismatch')
#     231
# --> 232         y = self._matvec(x)
#     233
#     234         if isinstance(x, np.matrix):
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/sparse/linalg/interface.py in _matvec(self, x)
#     528
#     529     def _matvec(self, x):
# --> 530         return self.__matvec_impl(x)
#     531
#     532     def _rmatvec(self, x):
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/optimize/nonlin.py in matvec(self, v)
#    1565             return 0*v
#    1566         sc = self.omega / nv
# -> 1567         r = (self.func(self.x0 + sc*v) - self.f0) / sc
#    1568         if not np.all(np.isfinite(r)) and np.all(np.isfinite(v)):
#    1569             raise ValueError('Function returned non-finite results')
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/optimize/nonlin.py in <lambda>(z)
#     270
#     271     x0 = _as_inexact(x0)
# --> 272     func = lambda z: _as_inexact(F(_array_like(z, x0))).flatten()
#     273     x = x0.flatten()
#     274
#
# ~/local/python3.9/lib/python3.9/site-packages/scipy/optimize/_root.py in f(x)
#     289         else:
#     290             def f(x):
# --> 291                 return fun(x, *args)
#     292     else:
#     293         f = fun
#
# ~/Python/pypde/dns/rbc2d_base.py in steady_fun(self, X, NS)
#     251         """
#     252         NS.T.vhat[:], NS.U.vhat[:], NS.V.vhat[:] = NS.reshape(X)
# --> 253         NS.update()
#     254         Y = NS.vectorify()
#     255         return (Y - X) / NS.dt
#
# ~/Python/pypde/dns/rbc2d.py in update(self)
#     337             # Solve Ux
#     338             self.update_U(stage=rk)
# --> 339             self.update_V(That, stage=rk)
#     340
#     341             # Divergence of Velocity
#
# ~/Python/pypde/dns/rbc2d.py in update_V(self, That, stage)
#     223
#     224         # Non-Linear Convection
# --> 225         rhs -= self.dt * self.b[stage] * self.conv_term(self.V, self.ux, self.uz)
#     226         if self.c[stage] != 0:
#     227             rhs -= (
#
# ~/Python/pypde/dns/rbc2d.py in conv_term(self, field, ux, uz, add_bc)
#     161     def conv_term(self, field, ux, uz, add_bc=None):
#     162         tic = time.perf_counter()
# --> 163         conv = convective_term(
#     164             field,
#     165             ux,
#
# ~/Python/pypde/pypde/field_operations.py in convective_term(v_field, ux, uz, deriv_field, add_bc, dealias, scale)
#     152         Transform to spectral space via conv_field.forward()
#     153     """
# --> 154     conv = conv_term(v_field, ux, (1, 0), deriv_field, dealias, scale=scale)
#     155     conv += conv_term(v_field, uz, (0, 1), deriv_field, dealias, scale=scale)
#     156
#
# ~/Python/pypde/pypde/field_operations.py in conv_term(v_field, u, deriv, deriv_field, dealias, scale)
#     116
#     117     # dvdx
# --> 118     vhat = grad(v_field, deriv, return_field=False, scale=scale)
#     119     if dealias:
#     120         dvdx = deriv_field.dealias.backward(vhat)
#
# ~/Python/pypde/pypde/field_operations.py in grad(field, deriv, return_field, scale)
#      43         if scale is not None:
#      44             assert len(scale) == field.ndim
# ---> 45             dvhat /= scale[axis] ** deriv[axis]
#      46
#      47     if return_field:
#
# KeyboardInterrupt:

# %%
NSA.iterate(150.0)
NSA.plot()

NS.U.vhat[:] = NSA.U.vhat[:]
NS.V.vhat[:] = NSA.V.vhat[:]
NS.T.vhat[:] = NSA.T.vhat[:]
Nuz, Nuv = NS.eval_Nu()

NS.solve_steady_state(maxiter=500)
Nuz, Nuv = NS.eval_Nu()
NS.plot() 
NS.solve_stability()
NS.write(add_time=False)
# Out:
# Time: 81.000
# Divergence   : 1.49e-02
# Divergence NS: 1.49e-01
#  |U| = 5.59e-03
#  |V| = 4.78e-03
#  |T| = 7.07e-04
# Time: 82.000
# Divergence   : 1.46e-02
# Divergence NS: 1.46e-01
#  |U| = 5.49e-03
#  |V| = 4.69e-03
#  |T| = 6.94e-04
# Time: 83.000
# Divergence   : 1.43e-02
# Divergence NS: 1.43e-01
#  |U| = 5.38e-03
#  |V| = 4.60e-03
#  |T| = 6.81e-04
# Time: 84.000
# Divergence   : 1.40e-02
# Divergence NS: 1.40e-01
#  |U| = 5.28e-03
#  |V| = 4.51e-03
#  |T| = 6.68e-04
# Time: 85.000
# Divergence   : 1.37e-02
# Divergence NS: 1.37e-01
#  |U| = 5.17e-03
#  |V| = 4.42e-03
#  |T| = 6.56e-04
# Time: 86.000
# Divergence   : 1.34e-02
# Divergence NS: 1.34e-01
#  |U| = 5.07e-03
#  |V| = 4.33e-03
#  |T| = 6.44e-04
# Time: 87.000
# Divergence   : 1.31e-02
# Divergence NS: 1.32e-01
#  |U| = 4.97e-03
#  |V| = 4.25e-03
#  |T| = 6.31e-04
# Time: 88.000
# Divergence   : 1.29e-02
# Divergence NS: 1.29e-01
#  |U| = 4.87e-03
#  |V| = 4.17e-03
#  |T| = 6.20e-04
# Time: 89.000
# Divergence   : 1.26e-02
# Divergence NS: 1.26e-01
#  |U| = 4.78e-03
#  |V| = 4.08e-03
#  |T| = 6.08e-04
# Time: 90.000
# Divergence   : 1.23e-02
# Divergence NS: 1.23e-01
#  |U| = 4.68e-03
#  |V| = 4.00e-03
#  |T| = 5.97e-04
# Time: 91.000
# Divergence   : 1.21e-02
# Divergence NS: 1.21e-01
#  |U| = 4.59e-03
#  |V| = 3.92e-03
#  |T| = 5.85e-04
# Time: 92.000
# Divergence   : 1.18e-02
# Divergence NS: 1.18e-01
#  |U| = 4.50e-03
#  |V| = 3.85e-03
#  |T| = 5.74e-04
# Time: 93.000
# Divergence   : 1.15e-02
# Divergence NS: 1.15e-01
#  |U| = 4.41e-03
#  |V| = 3.77e-03
#  |T| = 5.63e-04
# Time: 94.000
# Divergence   : 1.13e-02
# Divergence NS: 1.13e-01
#  |U| = 4.32e-03
#  |V| = 3.69e-03
#  |T| = 5.53e-04
# Time: 95.000
# Divergence   : 1.10e-02
# Divergence NS: 1.10e-01
#  |U| = 4.23e-03
#  |V| = 3.62e-03
#  |T| = 5.42e-04
# Time: 96.000
# Divergence   : 1.08e-02
# Divergence NS: 1.08e-01
#  |U| = 4.14e-03
#  |V| = 3.54e-03
#  |T| = 5.32e-04
# Time: 97.000
# Divergence   : 1.05e-02
# Divergence NS: 1.06e-01
#  |U| = 4.06e-03
#  |V| = 3.47e-03
#  |T| = 5.22e-04
# Time: 98.000
# Divergence   : 1.03e-02
# Divergence NS: 1.03e-01
#  |U| = 3.98e-03
#  |V| = 3.40e-03
#  |T| = 5.12e-04
# Time: 99.000
# Divergence   : 1.01e-02
# Divergence NS: 1.01e-01
#  |U| = 3.89e-03
#  |V| = 3.33e-03
#  |T| = 5.02e-04
# Time: 100.000
# Divergence   : 9.85e-03
# Divergence NS: 9.87e-02
#  |U| = 3.81e-03
#  |V| = 3.26e-03
#  |T| = 4.92e-04
# Time: 101.000
# Divergence   : 9.63e-03
# Divergence NS: 9.64e-02
#  |U| = 3.73e-03
#  |V| = 3.19e-03
#  |T| = 4.83e-04
# Time: 102.000
# Divergence   : 9.41e-03
# Divergence NS: 9.42e-02
#  |U| = 3.66e-03
#  |V| = 3.13e-03
#  |T| = 4.73e-04
# Time: 103.000
# Divergence   : 9.19e-03
# Divergence NS: 9.20e-02
#  |U| = 3.58e-03
#  |V| = 3.06e-03
#  |T| = 4.64e-04
# Time: 104.000
# Divergence   : 8.98e-03
# Divergence NS: 8.99e-02
#  |U| = 3.50e-03
#  |V| = 3.00e-03
#  |T| = 4.55e-04
# Time: 105.000
# Divergence   : 8.77e-03
# Divergence NS: 8.78e-02
#  |U| = 3.43e-03
#  |V| = 2.93e-03
#  |T| = 4.46e-04
# Time: 106.000
# Divergence   : 8.56e-03
# Divergence NS: 8.57e-02
#  |U| = 3.36e-03
#  |V| = 2.87e-03
#  |T| = 4.37e-04
# Time: 107.000
# Divergence   : 8.36e-03
# Divergence NS: 8.37e-02
#  |U| = 3.28e-03
#  |V| = 2.81e-03
#  |T| = 4.29e-04
# Time: 108.000
# Divergence   : 8.15e-03
# Divergence NS: 8.17e-02
#  |U| = 3.21e-03
#  |V| = 2.75e-03
#  |T| = 4.20e-04
# Time: 109.000
# Divergence   : 7.96e-03
# Divergence NS: 7.97e-02
#  |U| = 3.14e-03
#  |V| = 2.69e-03
#  |T| = 4.12e-04
# Time: 110.000
# Divergence   : 7.76e-03
# Divergence NS: 7.77e-02
#  |U| = 3.08e-03
#  |V| = 2.63e-03
#  |T| = 4.04e-04
# Time: 111.000
# Divergence   : 7.57e-03
# Divergence NS: 7.58e-02
#  |U| = 3.01e-03
#  |V| = 2.57e-03
#  |T| = 3.95e-04
# Time: 112.000
# Divergence   : 7.39e-03
# Divergence NS: 7.40e-02
#  |U| = 2.94e-03
#  |V| = 2.52e-03
#  |T| = 3.88e-04
# Time: 113.000
# Divergence   : 7.20e-03
# Divergence NS: 7.21e-02
#  |U| = 2.88e-03
#  |V| = 2.46e-03
#  |T| = 3.80e-04
# Time: 114.000
# Divergence   : 7.02e-03
# Divergence NS: 7.03e-02
#  |U| = 2.81e-03
#  |V| = 2.40e-03
#  |T| = 3.72e-04
# Time: 115.000
# Divergence   : 6.84e-03
# Divergence NS: 6.85e-02
#  |U| = 2.75e-03
#  |V| = 2.35e-03
#  |T| = 3.64e-04
# Time: 116.000
# Divergence   : 6.66e-03
# Divergence NS: 6.67e-02
#  |U| = 2.69e-03
#  |V| = 2.30e-03
#  |T| = 3.57e-04
# Time: 117.000
# Divergence   : 6.49e-03
# Divergence NS: 6.50e-02
#  |U| = 2.63e-03
#  |V| = 2.24e-03
#  |T| = 3.50e-04
# Time: 118.000
# Divergence   : 6.32e-03
# Divergence NS: 6.33e-02
#  |U| = 2.57e-03
#  |V| = 2.19e-03
#  |T| = 3.43e-04
# Time: 119.000
# Divergence   : 6.15e-03
# Divergence NS: 6.16e-02
#  |U| = 2.51e-03
#  |V| = 2.14e-03
#  |T| = 3.35e-04
# Time: 120.000
# Divergence   : 5.99e-03
# Divergence NS: 6.00e-02
#  |U| = 2.45e-03
#  |V| = 2.09e-03
#  |T| = 3.29e-04
# Time: 121.000
# Divergence   : 5.83e-03
# Divergence NS: 5.83e-02
#  |U| = 2.39e-03
#  |V| = 2.04e-03
#  |T| = 3.22e-04
# Time: 122.000
# Divergence   : 5.67e-03
# Divergence NS: 5.67e-02
#  |U| = 2.34e-03
#  |V| = 1.99e-03
#  |T| = 3.15e-04
# Time: 123.000
# Divergence   : 5.51e-03
# Divergence NS: 5.52e-02
#  |U| = 2.28e-03
#  |V| = 1.95e-03
#  |T| = 3.08e-04
# Time: 124.000
# Divergence   : 5.35e-03
# Divergence NS: 5.36e-02
#  |U| = 2.23e-03
#  |V| = 1.90e-03
#  |T| = 3.02e-04
# Time: 125.000
# Divergence   : 5.20e-03
# Divergence NS: 5.21e-02
#  |U| = 2.17e-03
#  |V| = 1.85e-03
#  |T| = 2.96e-04
# Time: 126.000
# Divergence   : 5.05e-03
# Divergence NS: 5.06e-02
#  |U| = 2.12e-03
#  |V| = 1.81e-03
#  |T| = 2.89e-04
# Time: 127.000
# Divergence   : 4.90e-03
# Divergence NS: 4.91e-02
#  |U| = 2.07e-03
#  |V| = 1.76e-03
#  |T| = 2.83e-04
# Time: 128.000
# Divergence   : 4.76e-03
# Divergence NS: 4.77e-02
#  |U| = 2.02e-03
#  |V| = 1.72e-03
#  |T| = 2.77e-04
# Time: 129.000
# Divergence   : 4.62e-03
# Divergence NS: 4.62e-02
#  |U| = 1.97e-03
#  |V| = 1.68e-03
#  |T| = 2.71e-04
# Time: 130.000
# Divergence   : 4.48e-03
# Divergence NS: 4.48e-02
#  |U| = 1.92e-03
#  |V| = 1.64e-03
#  |T| = 2.66e-04
# Time: 131.000
# Divergence   : 4.34e-03
# Divergence NS: 4.34e-02
#  |U| = 1.87e-03
#  |V| = 1.59e-03
#  |T| = 2.60e-04
# Time: 132.000
# Divergence   : 4.20e-03
# Divergence NS: 4.21e-02
#  |U| = 1.82e-03
#  |V| = 1.55e-03
#  |T| = 2.54e-04
# Time: 133.000
# Divergence   : 4.07e-03
# Divergence NS: 4.07e-02
#  |U| = 1.78e-03
#  |V| = 1.51e-03
#  |T| = 2.49e-04
# Time: 134.000
# Divergence   : 3.94e-03
# Divergence NS: 3.94e-02
#  |U| = 1.73e-03
#  |V| = 1.47e-03
#  |T| = 2.43e-04
# Time: 135.000
# Divergence   : 3.81e-03
# Divergence NS: 3.81e-02
#  |U| = 1.69e-03
#  |V| = 1.44e-03
#  |T| = 2.38e-04
# Time: 136.000
# Divergence   : 3.68e-03
# Divergence NS: 3.68e-02
#  |U| = 1.64e-03
#  |V| = 1.40e-03
#  |T| = 2.33e-04
# Time: 137.000
# Divergence   : 3.56e-03
# Divergence NS: 3.56e-02
#  |U| = 1.60e-03
#  |V| = 1.36e-03
#  |T| = 2.28e-04
# Time: 138.000
# Divergence   : 3.43e-03
# Divergence NS: 3.44e-02
#  |U| = 1.56e-03
#  |V| = 1.32e-03
#  |T| = 2.23e-04
# Time: 139.000
# Divergence   : 3.31e-03
# Divergence NS: 3.31e-02
#  |U| = 1.51e-03
#  |V| = 1.29e-03
#  |T| = 2.18e-04
# Time: 140.000
# Divergence   : 3.19e-03
# Divergence NS: 3.20e-02
#  |U| = 1.47e-03
#  |V| = 1.25e-03
#  |T| = 2.13e-04
# Time: 141.000
# Divergence   : 3.07e-03
# Divergence NS: 3.08e-02
#  |U| = 1.43e-03
#  |V| = 1.22e-03
#  |T| = 2.09e-04
# Time: 142.000
# Divergence   : 2.96e-03
# Divergence NS: 2.96e-02
#  |U| = 1.39e-03
#  |V| = 1.19e-03
#  |T| = 2.04e-04
# Time: 143.000
# Divergence   : 2.85e-03
# Divergence NS: 2.85e-02
#  |U| = 1.35e-03
#  |V| = 1.15e-03
#  |T| = 2.00e-04
# Time: 144.000
# Divergence   : 2.74e-03
# Divergence NS: 2.74e-02
#  |U| = 1.32e-03
#  |V| = 1.12e-03
#  |T| = 1.95e-04
# Time: 145.000
# Divergence   : 2.63e-03
# Divergence NS: 2.63e-02
#  |U| = 1.28e-03
#  |V| = 1.09e-03
#  |T| = 1.91e-04
# Time: 146.000
# Divergence   : 2.52e-03
# Divergence NS: 2.52e-02
#  |U| = 1.24e-03
#  |V| = 1.06e-03
#  |T| = 1.87e-04
# Time: 147.000
# Divergence   : 2.41e-03
# Divergence NS: 2.41e-02
#  |U| = 1.21e-03
#  |V| = 1.03e-03
#  |T| = 1.83e-04
# Time: 148.000
# Divergence   : 2.31e-03
# Divergence NS: 2.31e-02
#  |U| = 1.17e-03
#  |V| = 9.99e-04
#  |T| = 1.79e-04
# Time: 149.000
# Divergence   : 2.21e-03
# Divergence NS: 2.21e-02
#  |U| = 1.14e-03
#  |V| = 9.70e-04
#  |T| = 1.75e-04
# Time: 150.000
# Divergence   : 2.11e-03
# Divergence NS: 2.11e-02
#  |U| = 1.10e-03
#  |V| = 9.42e-04
#  |T| = 1.71e-04
# Nubot: 2.457996e+00
# Nutop: 2.457996e+00
# Nuvol: 2.231846e+00
# 0:  |F(x)| = 0.000185762; step 0.00455828
# 1:  |F(x)| = 0.000181105; step 0.0056896
# 2:  |F(x)| = 0.00104285; step 1
# 3:  |F(x)| = 0.000798477; step 0.145722
# 4:  |F(x)| = 0.000742722; step 0.0990629
# 5:  |F(x)| = 0.000747743; step 0.0578928
# 6:  |F(x)| = 0.000320839; step 1
# 7:  |F(x)| = 0.000309952; step 0.0334826
# 8:  |F(x)| = 0.000286355; step 0.00352002
# 9:  |F(x)| = 0.000280057; step 0.0124781
# 10:  |F(x)| = 0.00027709; step 0.0112072
# 11:  |F(x)| = 0.000274123; step 0.00649074
# 12:  |F(x)| = 0.000291536; step 0.0219137
# 13:  |F(x)| = 0.000214693; step 0.418325
# 14:  |F(x)| = 0.0135771; step 1
# 15:  |F(x)| = 0.00880777; step 1
# 16:  |F(x)| = 0.0204491; step 1
# 17:  |F(x)| = 0.00966841; step 1
# 18:  |F(x)| = 0.000972779; step 1
# 19:  |F(x)| = 0.022297; step 1
# 20:  |F(x)| = 0.00907541; step 1
# 21:  |F(x)| = 0.00420456; step 1
# 22:  |F(x)| = 0.0137574; step 1
# 23:  |F(x)| = 0.00651137; step 1
# 24:  |F(x)| = 0.00582324; step 0.0166055
# 25:  |F(x)| = 0.00514699; step 0.102037
# 26:  |F(x)| = 0.00542446; step 0.260076
# 27:  |F(x)| = 0.00601178; step 0.45149
# 28:  |F(x)| = 0.00251198; step 1
# 29:  |F(x)| = 0.0120959; step 1
# 30:  |F(x)| = 0.00244114; step 1
# 31:  |F(x)| = 0.00231795; step 0.0243419
# 32:  |F(x)| = 0.0017433; step 0.102308
# 33:  |F(x)| = 0.00155911; step 0.027142
# 34:  |F(x)| = 0.00145698; step 0.0113924
# 35:  |F(x)| = 0.00137902; step 0.00612225
# 36:  |F(x)| = 0.00142904; step 0.0301269
# 37:  |F(x)| = 0.00117897; step 0.0663218
# 38:  |F(x)| = 0.0117921; step 1
# 39:  |F(x)| = 0.00841022; step 1
# 40:  |F(x)| = 0.00459358; step 1
# 41:  |F(x)| = 0.00216506; step 1
# 42:  |F(x)| = 0.000179159; step 1
# 43:  |F(x)| = 0.000260716; step 1
# 44:  |F(x)| = 0.000337137; step 1
# 45:  |F(x)| = 0.00405694; step 1
# 46:  |F(x)| = 0.00110515; step 1
# 47:  |F(x)| = 0.000821393; step 1
# 48:  |F(x)| = 0.00070554; step 1
# 49:  |F(x)| = 0.000520006; step 0.455809
# 50:  |F(x)| = 0.000521799; step 0.00368201
# 51:  |F(x)| = 7.00096e-05; step 1
# 52:  |F(x)| = 7.18044e-05; step 0.496577
# 53:  |F(x)| = 0.00115968; step 1
# 54:  |F(x)| = 0.000362118; step 1
# 55:  |F(x)| = 0.000337542; step 0.0102484
# 56:  |F(x)| = 0.000369386; step 0.0132622
# 57:  |F(x)| = 0.000306385; step 0.0386036
# 58:  |F(x)| = 0.0010477; step 1
# 59:  |F(x)| = 0.000254259; step 1
# 60:  |F(x)| = 0.00110562; step 1
# 61:  |F(x)| = 0.00136717; step 1
# 62:  |F(x)| = 0.000353197; step 1
# 63:  |F(x)| = 0.000352403; step 0.0108547
# 64:  |F(x)| = 8.23283e-05; step 0.468786
# 65:  |F(x)| = 0.00125738; step 1
# 66:  |F(x)| = 0.00047759; step 1
# 67:  |F(x)| = 0.000439965; step 1
# 68:  |F(x)| = 0.000189773; step 1
# 69:  |F(x)| = 8.95255e-05; step 1
# 70:  |F(x)| = 7.52364e-05; step 0.253366
# 71:  |F(x)| = 0.000130597; step 1
# 72:  |F(x)| = 3.71431e-05; step 1
# 73:  |F(x)| = 2.52082e-05; step 1
# 74:  |F(x)| = 1.57596e-05; step 1
# 75:  |F(x)| = 2.30075e-05; step 0.0769404
# 76:  |F(x)| = 1.29762e-05; step 1
# 77:  |F(x)| = 1.34167e-05; step 0.295128
# 78:  |F(x)| = 7.25877e-05; step 1
# 79:  |F(x)| = 4.87395e-05; step 1
# 80:  |F(x)| = 3.1409e-05; step 1
# 81:  |F(x)| = 6.24751e-05; step 1
# 82:  |F(x)| = 2.55902e-05; step 0.256679
# 83:  |F(x)| = 1.35824e-05; step 1
# 84:  |F(x)| = 0.000418216; step 1
# 85:  |F(x)| = 3.05673e-05; step 1
# 86:  |F(x)| = 7.03215e-06; step 1
# 87:  |F(x)| = 7.67262e-06; step 1
# 88:  |F(x)| = 0.000108676; step 1
# 89:  |F(x)| = 4.19696e-05; step 1
# 90:  |F(x)| = 1.09539e-05; step 1
# 91:  |F(x)| = 1.31555e-05; step 1
# 92:  |F(x)| = 4.69086e-06; step 1
# 93:  |F(x)| = 1.78438e-06; step 1
# 94:  |F(x)| = 6.88642e-07; step 1
# 95:  |F(x)| = 6.89267e-07; step 0.0632696
# 96:  |F(x)| = 6.91574e-07; step 0.043264
# 97:  |F(x)| = 2.94276e-06; step 1
# 98:  |F(x)| = 6.69655e-07; step 1
# 99:  |F(x)| = 6.6988e-07; step 0.331388
# 100:  |F(x)| = 6.6908e-07; step 0.0648888
# 101:  |F(x)| = 7.54418e-07; step 1
# 102:  |F(x)| = 6.30825e-07; step 1
# 103:  |F(x)| = 6.29035e-07; step 0.0843104
# 104:  |F(x)| = 6.27944e-07; step 0.0534887
# 105:  |F(x)| = 6.26787e-07; step 0.030899
# 106:  |F(x)| = 1.42812e-06; step 1
# 107:  |F(x)| = 1.38024e-06; step 0.0286035
# 108:  |F(x)| = 7.46982e-07; step 1
# 109:  |F(x)| = 6.67788e-07; step 1
# 110:  |F(x)| = 6.74797e-06; step 1
# 111:  |F(x)| = 1.38759e-06; step 1
# 112:  |F(x)| = 1.23241e-06; step 0.0145537
# 113:  |F(x)| = 8.44865e-07; step 0.000431742
# 114:  |F(x)| = 6.01266e-06; step 1
# 115:  |F(x)| = 1.63529e-06; step 1
# 116:  |F(x)| = 2.27583e-06; step 1
# 117:  |F(x)| = 5.06384e-06; step 1
# 118:  |F(x)| = 1.24916e-06; step 1
# 119:  |F(x)| = 4.02484e-07; step 1
# 120:  |F(x)| = 4.04877e-07; step 1
# 121:  |F(x)| = 3.64267e-07; step 0.000477194
# 122:  |F(x)| = 3.62389e-07; step 0.00094714
# 123:  |F(x)| = 3.59114e-07; step 0.00775282
# 124:  |F(x)| = 3.44274e-07; step 0.00606085
# 125:  |F(x)| = 1.46906e-06; step 1
# 126:  |F(x)| = 1.79676e-06; step 1
# 127:  |F(x)| = 1.48844e-06; step 1
# 128:  |F(x)| = 2.0992e-07; step 1
# 129:  |F(x)| = 1.24446e-07; step 0.00197721
# 130:  |F(x)| = 1.24341e-07; step 0.000801413
# 131:  |F(x)| = 1.24287e-07; step 0.000126368
# 132:  |F(x)| = 1.22667e-07; step 0.0180365
# 133:  |F(x)| = 1.22457e-07; step 0.00905619
# 134:  |F(x)| = 1.22236e-07; step 0.0158815
# 135:  |F(x)| = 1.13008e-07; step 0.446348
# 136:  |F(x)| = 1.1211e-07; step 0.00688773
# 137:  |F(x)| = 1.1193e-07; step 0.0253258
# 138:  |F(x)| = 1.11433e-07; step 0.0331047
# 139:  |F(x)| = 1.05927e-06; step 1
# 140:  |F(x)| = 1.29545e-07; step 1
# 141:  |F(x)| = 7.38755e-08; step 1
# 142:  |F(x)| = 5.16435e-08; step 0.200082
# 143:  |F(x)| = 4.48264e-08; step 0.00349361
# 144:  |F(x)| = 4.32989e-08; step 0.274413
# 145:  |F(x)| = 3.17618e-08; step 0.00492039
# 146:  |F(x)| = 4.09429e-07; step 1
# 147:  |F(x)| = 2.07839e-07; step 1
# 148:  |F(x)| = 5.58546e-08; step 0.385293
# 149:  |F(x)| = 2.96119e-08; step 0.110773
# 150:  |F(x)| = 1.31853e-08; step 1
# 151:  |F(x)| = 2.18786e-08; step 1
# 152:  |F(x)| = 2.07953e-08; step 0.000334327
# 153:  |F(x)| = 2.53489e-08; step 0.459437
# 154:  |F(x)| = 2.22535e-08; step 0.000459095
# 155:  |F(x)| = 1.34004e-08; step 1
# 156:  |F(x)| = 9.93021e-09; step 0.0139937
# Nubot: 2.523302e+00
# Nutop: 2.523294e+00
# Nuvol: 2.286539e+00
# Solve stability ...
# Initialize rk3 ...
#    5 largest eigenvalues:
#    5: 0.0000e+00 -3.3080e-01j
#    4: 0.0000e+00 -1.2688e-01j
#    3: 0.0000e+00 -1.0971e-02j
#    2: 0.0000e+00 7.3697e-02j
#    1: 0.0000e+00 1.2817e-01j
# Stability calculation finished!
# Write T.h5 ...
# Write U.h5 ...
# Write V.h5 ...
# Write P.h5 ...

# %%
NS2 = rbc2d.NavierStokes(
    adiabatic=adiabatic,
    shape=shape,
    dt=0.1,
    tsave=1.0,
    Ra=R,
    Pr=Pr,
    dealias=True,
    integrator="rk3",
    beta=1.0,
    aspect=aspect,
)
NS2.U.vhat[:] = NS.U.vhat[:].copy()
NS2.V.vhat[:] = NS.V.vhat[:].copy()
NS2.T.vhat[:] = NS.T.vhat[:].copy()
# Out:
# Initialize rk3 ...

# %%
NS2.iterate(80)
# Out:
# Time: 41.000
# Divergence: 7.93e-05
# Time: 42.000
# Divergence: 7.94e-05
# Time: 43.000
# Divergence: 7.95e-05
# Time: 44.000
# Divergence: 7.96e-05
# Time: 45.000
# Divergence: 7.98e-05
# Time: 46.000
# Divergence: 7.99e-05
# Time: 47.000
# Divergence: 8.01e-05
# Time: 48.000
# Divergence: 8.03e-05
# Time: 49.000
# Divergence: 8.05e-05
# Time: 50.000
# Divergence: 8.08e-05
# Time: 51.000
# Divergence: 8.10e-05
# Time: 52.000
# Divergence: 8.12e-05
# Time: 53.000
# Divergence: 8.14e-05
# Time: 54.000
# Divergence: 8.16e-05
# Time: 55.000
# Divergence: 8.18e-05
# Time: 56.000
# Divergence: 8.19e-05
# Time: 57.000
# Divergence: 8.20e-05
# Time: 58.000
# Divergence: 8.20e-05
# Time: 59.000
# Divergence: 8.19e-05
# Time: 60.000
# Divergence: 8.16e-05
# Time: 61.000
# Divergence: 8.12e-05
# Time: 62.000
# Divergence: 8.06e-05
# Time: 63.000
# Divergence: 7.98e-05
# Time: 64.000
# Divergence: 7.86e-05
# Time: 65.000
# Divergence: 7.72e-05
# Time: 66.000
# Divergence: 7.57e-05
# Time: 67.000
# Divergence: 7.44e-05
# Time: 68.000
# Divergence: 7.41e-05
# Time: 69.000
# Divergence: 7.63e-05
# Time: 70.000
# Divergence: 8.28e-05
# Time: 71.000
# Divergence: 9.23e-05
# Time: 72.000
# Divergence: 9.06e-05
# Time: 73.000
# Divergence: 8.65e-05
# Time: 74.000
# Divergence: 1.10e-04
# Time: 75.000
# Divergence: 1.20e-04
# Time: 76.000
# Divergence: 1.14e-04
# Time: 77.000
# Divergence: 1.03e-04
# Time: 78.000
# Divergence: 9.32e-05
# Time: 79.000
# Divergence: 8.56e-05
# Time: 80.000
# Divergence: 8.16e-05

# %%
#  Add inhomogeneous part
for i,v in enumerate(NS2.T.V):
        if NS2.T.V[i][0,0] < 0.1:
            NS2.T.V[i] += NS2.Tbc.v

anim = NS2.T.animate(duration=4)
anim.save('out/anim.gif', writer='imagemagick', fps=20)
HTML(anim.to_jshtml())
# Out:
# /home/philipp/Python/pypde/pypde/plot/colors.py:27: UserWarning: Trying to register the cmap 'gfcmap' which already exists.
#   plt.cm.register_cmap(name="gfcmap", cmap=gfcmap())
# Save animation to out/anim.mp4
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img490579d5b0494eb999c110f4a6b66359">
#   <div class="anim-controls">
#     <input id="_anim_slider490579d5b0494eb999c110f4a6b66359" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim490579d5b0494eb999c110f4a6b66359.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim490579d5b0494eb999c110f4a6b66359.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim490579d5b0494eb999c110f4a6b66359.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim490579d5b0494eb999c110f4a6b66359.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim490579d5b0494eb999c110f4a6b66359.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim490579d5b0494eb999c110f4a6b66359.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim490579d5b0494eb999c110f4a6b66359.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim490579d5b0494eb999c110f4a6b66359.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim490579d5b0494eb999c110f4a6b66359.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim490579d5b0494eb999c110f4a6b66359.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select490579d5b0494eb999c110f4a6b66359"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_490579d5b0494eb999c110f4a6b66359"
#              >
#       <label for="_anim_radio1_490579d5b0494eb999c110f4a6b66359">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_490579d5b0494eb999c110f4a6b66359"
#              checked>
#       <label for="_anim_radio2_490579d5b0494eb999c110f4a6b66359">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_490579d5b0494eb999c110f4a6b66359"
#              >
#       <label for="_anim_radio3_490579d5b0494eb999c110f4a6b66359">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img490579d5b0494eb999c110f4a6b66359";
#     var slider_id = "_anim_slider490579d5b0494eb999c110f4a6b66359";
#     var loop_select_id = "_anim_loop_select490579d5b0494eb999c110f4a6b66359";
#     var frames = new Array(80);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA
